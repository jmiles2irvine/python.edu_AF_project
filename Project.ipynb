# %%
import pandas

def main():
    district, districtGeometry, districtType, districtRatings, districtAEA, \
        districtDistinctions, districtReference, districtECHS = readDistrictFiles()

def readDistrictFiles():
    district = pandas.read_csv('tea directory districts.csv', usecols= {0,1,2,3,4,14}, dtype={'DISTRICT_NUMBER': object, 
                                                                                              'COUNTY_NUMBER': object, 
                                                                                              'REGION_NUMBER': object})
    districtGeometry = pandas.read_csv('district_geometry.csv', usecols={'DISTRICT_N','Area'}, dtype={'DISTRICT_N': object})
    districtGeometry['DISTRICT_N']=fixZeros(list(districtGeometry['DISTRICT_N']))
    districtType = pandas.read_csv('district type.csv', usecols = {1,2,3}, dtype={'District': object})
    districtRatings = pandas.read_csv('district ratings.csv', dtype={'District_Number': object})
    districtAEA = pandas.read_csv('aea districts.csv', dtype={'District Number': object})
    districtDistinctions = pandas.read_excel('district_distinctions.xlsx', sheetname=0, converters={'DISTRICT':str})
    districtReference = pandas.read_excel('district_reference.xlsx', sheetname=0, converters={'DISTRICT':str})
    districtECHS = pandas.read_excel('Early College High Schools 15-16 list.xlsx', sheetname=0, converters={'DistrictNumber':str,
                                                                                                            'CampusNumber':str})
    #wanting to use this to read in colLabel to a data frame, but haven't figured out how to do this.
    #districtDistinctionsDictionary =  pandas.read_excel('district_distinctions.xlsx', sheetname='Sheet2')
    #colLabels(districtDistinctions,districtDistinctionsDictionary)
    return district, districtGeometry, districtType, districtRatings, districtAEA, \
        districtDistinctions, districtReference, districtECHS


#these excel files have a sheet which contains labels for the column names, I want to write something which
#reads these column labels into the data frame, but I haven't figured this out yet
def colLabels(data1, data2):
    dataheaders = data1.columns.values
    print(dataheaders)
    print(data2['NAME'])
    

def fixZeros(str):
    #pass a list of numbers formatted as string and fill in the missing leading zeros
    maxlen = max(len(i) for i in str)
    for i in range(len(str)):
        if len(str[i]) < maxlen:
            str[i] = "0"*(maxlen - len(str[i]))+str[i]
    return str
    
main()
# Out:
#    Year DistrictNumber                      District CampusNumber  \
# 0  2016         003801  Pineywoods Community Academy    003801001
# 1  2016         011901                   Bastrop ISD    011901005
# 2  2016         011902                     Elgin ISD    011902001
# 3  2016         014906                   Killeen ISD    014906013
# 4  2016         015805  New Frontiers Charter School    015805001
# 5  2016         015904                Harlandale ISD    015904011
# 6  2016         015907               San Antonio ISD    015907001
# 7  2016         015907               San Antonio ISD    015907025
# 8  2016         015907               San Antonio ISD    015907022
# 9  2016         015908         South San Antonio ISD    015908001
#
#                                         Campus               Location  \
# 0            PARAMUS Early College High School       Lufkin, TX 75904
# 1            Colorado River Collegiate Academy      Bastrop, TX 78602
# ...
